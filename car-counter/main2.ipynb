# %%
print(
# Out:
#   Cell In[7], line 1
#     print(
#           ^
# SyntaxError: unexpected EOF while parsing

# %%
powershell.exe -ExecutionPolicy ByPass -NoExit -Command "& 'C:\ProgramData\anaconda3\shell\condabin\conda-hook.ps1' ; conda activate 'C:\ProgramData\anaconda3' "

# %% [markdown]
# detect from image

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.pt')  # pretrained YOLOv8n model

# Run batched inference on a list of images
results = model(['image3.png'], stream=True)  # return a generator of Results objects

# Process results generator
for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
# Out:
# 0: 448x640 1 person, 2 cars, 116.0ms
# Speed: 4.5ms preprocess, 116.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)

# %% [markdown]
# yolo predict model=yolov8n.pt source=''http://192.168.191.50:8080/browserfs.html' imgsz=32

# %%
import cv2

cap = cv2.VideoCapture('rtsp://192.168.191.50:8080/h264.sdp')
cap.set(3, 640)
cap.set(4, 480)

while True:
    ret, img= cap.read()
    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
yolo predict model=yolov8n.pt source=0 imgsz=640

# %% [markdown]
# webcam

# %%
# source from https://dipankarmedh1.medium.com/real-time-object-detection-with-yolo-and-webcam-enhancing-your-computer-vision-skills-861b97c78993

from ultralytics import YOLO
import cv2
import math 
# start webcam
cap = cv2.VideoCapture('rtsp://192.168.191.50:8080/h264.sdp')


frames_count, fps, width, height = cap.get(cv2.CAP_PROP_FRAME_COUNT), cap.get(cv2.CAP_PROP_FPS), cap.get(
    cv2.CAP_PROP_FRAME_WIDTH), cap.get(cv2.CAP_PROP_FRAME_HEIGHT)

cap.set(3, int(width))
cap.set(4, int(height))

# Define the vertical line position
success, img = cap.read()
line_position = int(img.shape[1] / 2)

# Initialize variables for counting cars
cars_crossed_l_to_r = 0
cars_crossed_r_to_l = 0
car_ids = []
car_ids_crossed = []

# model
model = YOLO("yolov8n.pt")

# object classes
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]

while True:
    success, img = cap.read()
    results = model(img, stream=True)

    # Coordinates
    for r in results:
        boxes = r.boxes

        for box in boxes:
            # Bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)  # Convert to int values

            # Put box in cam
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # Confidence
            confidence = math.ceil((box.conf[0] * 100)) / 100
            print("Confidence --->", confidence)

            # Class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # Object details
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness) #classNames[cls]+str(box.id)

            # Count cars crossing the line
            if x1 < line_position and x2 > line_position:
                #if box.id not in car_ids:
                #car_ids.append(box.id)
                if y2 < 330: #changed
                    cars_crossed_r_to_l += 1                   
                else:
                    cars_crossed_l_to_r += 1
                    #car_ids_crossed.append(box.id)

    # Display the number of cars crossed     
    cv2.putText(img, "Cars Crossed l to r: " + str(cars_crossed_l_to_r), (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
    cv2.putText(img, "Cars Crossed r to l: " + str(cars_crossed_r_to_l), (10, 70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)


    # Draw the vertical line
    cv2.line(img, (line_position, 0), (line_position, img.shape[0]), (0, 255, 0), 2)


    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Confidence ---> 0.84
# Class name --> car
# Confidence ---> 0.59
# Class name --> car
# Confidence ---> 0.3
# Class name --> person
# 0: 448x640 1 person, 2 cars, 114.5ms
# Speed: 3.0ms preprocess, 114.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.79
# Class name --> car
# Confidence ---> 0.46
# Class name --> car
# Confidence ---> 0.3
# Class name --> person
# 0: 448x640 1 person, 2 cars, 157.4ms
# Speed: 4.0ms preprocess, 157.4ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.75
# Class name --> car
# Confidence ---> 0.66
# Class name --> car
# 0: 448x640 2 cars, 127.1ms
# Speed: 4.0ms preprocess, 127.1ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.75
# Class name --> car
# 0: 448x640 1 car, 103.9ms
# Speed: 3.0ms preprocess, 103.9ms inference, 2.8ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.71
# Class name --> car
# Confidence ---> 0.31
# Class name --> person
# 0: 448x640 1 person, 1 car, 106.5ms
# Speed: 3.2ms preprocess, 106.5ms inference, 3.5ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.66
# Class name --> car
# Confidence ---> 0.39
# Class name --> person
# 0: 448x640 1 person, 1 car, 99.4ms
# Speed: 2.6ms preprocess, 99.4ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.65
# Class name --> car
# 0: 448x640 1 car, 107.0ms
# Speed: 2.0ms preprocess, 107.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.72
# Class name --> car
# Confidence ---> 0.49
# Class name --> person
# 0: 448x640 1 person, 1 car, 95.5ms
# Speed: 2.0ms preprocess, 95.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.82
# Class name --> car
# Confidence ---> 0.6
# Class name --> person
# 0: 448x640 1 person, 1 car, 99.2ms
# Speed: 3.0ms preprocess, 99.2ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.67
# Class name --> car
# Confidence ---> 0.54
# Class name --> person
# 0: 448x640 1 person, 1 car, 95.5ms
# Speed: 3.0ms preprocess, 95.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.7
# Class name --> car
# Confidence ---> 0.66
# Class name --> person
# 0: 448x640 1 person, 1 car, 101.5ms
# Speed: 1.0ms preprocess, 101.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.62
# Class name --> person
# 0: 448x640 1 person, 92.5ms
# Speed: 2.0ms preprocess, 92.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.58
# Class name --> car
# 0: 448x640 1 person, 1 car, 92.5ms
# Speed: 3.0ms preprocess, 92.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.55
# Class name --> car
# Confidence ---> 0.52
# Class name --> person
# 0: 448x640 1 person, 1 car, 91.0ms
# Speed: 2.5ms preprocess, 91.0ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.51
# Class name --> person
# 0: 448x640 1 person, 106.4ms
# Speed: 3.0ms preprocess, 106.4ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.38
# Class name --> person
# 0: 448x640 1 person, 113.0ms
# Speed: 3.4ms preprocess, 113.0ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.38
# Class name --> person
# 0: 448x640 1 person, 97.8ms
# Speed: 2.7ms preprocess, 97.8ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.33
# Class name --> person
# 0: 448x640 1 person, 90.5ms
# Speed: 3.0ms preprocess, 90.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.39
# Class name --> person
# 0: 448x640 1 person, 91.0ms
# Speed: 3.0ms preprocess, 91.0ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.3
# Class name --> person
# 0: 448x640 1 person, 89.5ms
# Speed: 3.0ms preprocess, 89.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.26
# Class name --> person
# 0: 448x640 1 person, 88.1ms
# Speed: 3.0ms preprocess, 88.1ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 90.5ms
# Speed: 3.0ms preprocess, 90.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 89.5ms
# Speed: 3.0ms preprocess, 89.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 100.5ms
# Speed: 3.9ms preprocess, 100.5ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.34
# Class name --> person
# 0: 448x640 1 person, 130.3ms
# Speed: 3.2ms preprocess, 130.3ms inference, 3.2ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.39
# Class name --> person
# 0: 448x640 1 person, 97.0ms
# Speed: 2.6ms preprocess, 97.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.51
# Class name --> person
# 0: 448x640 1 person, 93.1ms
# Speed: 4.0ms preprocess, 93.1ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.54
# Class name --> person
# 0: 448x640 1 person, 93.5ms
# Speed: 2.0ms preprocess, 93.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.34
# Class name --> person
# 0: 448x640 1 person, 86.5ms
# Speed: 3.0ms preprocess, 86.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.45
# Class name --> person
# 0: 448x640 1 person, 89.5ms
# Speed: 3.0ms preprocess, 89.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.51
# Class name --> person
# 0: 448x640 1 person, 90.5ms
# Speed: 3.0ms preprocess, 90.5ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.41
# Class name --> person
# 0: 448x640 1 person, 85.5ms
# Speed: 3.0ms preprocess, 85.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.31
# Class name --> person
# 0: 448x640 1 person, 102.5ms
# Speed: 3.0ms preprocess, 102.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.31
# Class name --> person
# 0: 448x640 1 person, 103.5ms
# Speed: 3.0ms preprocess, 103.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.41
# Class name --> person
# 0: 448x640 1 person, 103.3ms
# Speed: 3.0ms preprocess, 103.3ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.28
# Class name --> car
# 0: 448x640 1 person, 1 car, 110.1ms
# Speed: 3.0ms preprocess, 110.1ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.7
# Class name --> car
# Confidence ---> 0.48
# Class name --> person
# 0: 448x640 1 person, 1 car, 96.3ms
# Speed: 4.0ms preprocess, 96.3ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.71
# Class name --> car
# Confidence ---> 0.56
# Class name --> person
# 0: 448x640 1 person, 1 car, 82.3ms
# Speed: 3.0ms preprocess, 82.3ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.71
# Class name --> car
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.46
# Class name --> car
# 0: 448x640 1 person, 2 cars, 94.6ms
# Speed: 2.0ms preprocess, 94.6ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.59
# Class name --> car
# Confidence ---> 0.33
# Class name --> person
# 0: 448x640 1 person, 1 car, 90.5ms
# Speed: 4.0ms preprocess, 90.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.64
# Class name --> car
# Confidence ---> 0.43
# Class name --> person
# 0: 448x640 1 person, 1 car, 88.5ms
# Speed: 4.0ms preprocess, 88.5ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.73
# Class name --> car
# Confidence ---> 0.4
# Class name --> person
# 0: 448x640 1 person, 1 car, 94.5ms
# Speed: 3.0ms preprocess, 94.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.72
# Class name --> car
# Confidence ---> 0.3
# Class name --> person
# 0: 448x640 1 person, 1 car, 90.1ms
# Speed: 2.0ms preprocess, 90.1ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.68
# Class name --> car
# 0: 448x640 1 car, 96.8ms
# Speed: 2.0ms preprocess, 96.8ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.79
# Class name --> car
# 0: 448x640 1 car, 93.8ms
# Speed: 2.7ms preprocess, 93.8ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.81
# Class name --> car
# 0: 448x640 1 car, 94.8ms
# Speed: 3.1ms preprocess, 94.8ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.75
# Class name --> car
# 0: 448x640 1 car, 88.0ms
# Speed: 4.5ms preprocess, 88.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.47
# Class name --> car
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.28
# Class name --> truck
# 0: 448x640 1 person, 1 car, 1 truck, 89.5ms
# Speed: 2.0ms preprocess, 89.5ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.59
# Class name --> car
# Confidence ---> 0.27
# Class name --> person
# 0: 448x640 1 person, 1 car, 92.1ms
# Speed: 2.0ms preprocess, 92.1ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.77
# Class name --> car
# 0: 448x640 1 car, 90.0ms
# Speed: 2.0ms preprocess, 90.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.77
# Class name --> car
# Confidence ---> 0.26
# Class name --> person
# 0: 448x640 1 person, 1 car, 86.5ms
# Speed: 2.0ms preprocess, 86.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.71
# Class name --> car
# Confidence ---> 0.33
# Class name --> person
# 0: 448x640 1 person, 1 car, 91.2ms
# Speed: 3.0ms preprocess, 91.2ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.58
# Class name --> car
# Confidence ---> 0.28
# Class name --> car
# 0: 448x640 2 cars, 86.5ms
# Speed: 2.0ms preprocess, 86.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.48
# Class name --> car
# 0: 448x640 1 car, 102.4ms
# Speed: 3.0ms preprocess, 102.4ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.31
# Class name --> car
# 0: 448x640 1 person, 1 car, 103.0ms
# Speed: 2.0ms preprocess, 103.0ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.33
# Class name --> car
# 0: 448x640 1 car, 105.6ms
# Speed: 4.0ms preprocess, 105.6ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 92.5ms
# Speed: 2.0ms preprocess, 92.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.26
# Class name --> person
# 0: 448x640 1 person, 90.5ms
# Speed: 2.0ms preprocess, 90.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 90.7ms
# Speed: 3.0ms preprocess, 90.7ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.39
# Class name --> person
# 0: 448x640 1 person, 92.2ms
# Speed: 3.0ms preprocess, 92.2ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.27
# Class name --> person
# 0: 448x640 1 person, 91.8ms
# Speed: 2.0ms preprocess, 91.8ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 90.5ms
# Speed: 3.0ms preprocess, 90.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 88.5ms
# Speed: 3.0ms preprocess, 88.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.5
# Class name --> car
# 0: 448x640 1 car, 101.9ms
# Speed: 3.0ms preprocess, 101.9ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.7
# Class name --> car
# 0: 448x640 1 car, 100.6ms
# Speed: 3.7ms preprocess, 100.6ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.61
# Class name --> car
# Confidence ---> 0.29
# Class name --> person
# 0: 448x640 1 person, 1 car, 97.8ms
# Speed: 3.7ms preprocess, 97.8ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.65
# Class name --> car
# Confidence ---> 0.45
# Class name --> person
# 0: 448x640 1 person, 1 car, 91.5ms
# Speed: 2.7ms preprocess, 91.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.68
# Class name --> car
# Confidence ---> 0.31
# Class name --> person
# 0: 448x640 1 person, 1 car, 93.5ms
# Speed: 3.0ms preprocess, 93.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.82
# Class name --> car
# Confidence ---> 0.49
# Class name --> person
# 0: 448x640 1 person, 1 car, 85.4ms
# Speed: 2.0ms preprocess, 85.4ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.78
# Class name --> car
# Confidence ---> 0.44
# Class name --> person
# 0: 448x640 1 person, 1 car, 99.2ms
# Speed: 3.0ms preprocess, 99.2ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.83
# Class name --> car
# Confidence ---> 0.43
# Class name --> person
# 0: 448x640 1 person, 1 car, 88.1ms
# Speed: 3.0ms preprocess, 88.1ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.85
# Class name --> car
# 0: 448x640 1 car, 93.0ms
# Speed: 3.0ms preprocess, 93.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.56
# Class name --> car
# Confidence ---> 0.32
# Class name --> person
# 0: 448x640 1 person, 1 car, 93.2ms
# Speed: 2.0ms preprocess, 93.2ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.57
# Class name --> car
# Confidence ---> 0.28
# Class name --> person
# 0: 448x640 1 person, 1 car, 95.5ms
# Speed: 4.0ms preprocess, 95.5ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.38
# Class name --> person
# 0: 448x640 1 person, 102.0ms
# Speed: 3.0ms preprocess, 102.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.58
# Class name --> car
# Confidence ---> 0.49
# Class name --> person
# 0: 448x640 1 person, 1 car, 104.3ms
# Speed: 3.2ms preprocess, 104.3ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.51
# Class name --> car
# 0: 448x640 1 car, 91.5ms
# Speed: 3.0ms preprocess, 91.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.69
# Class name --> car
# Confidence ---> 0.34
# Class name --> person
# 0: 448x640 1 person, 1 car, 84.5ms
# Speed: 4.0ms preprocess, 84.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.64
# Class name --> car
# Confidence ---> 0.44
# Class name --> person
# 0: 448x640 1 person, 1 car, 90.9ms
# Speed: 4.0ms preprocess, 90.9ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.46
# Class name --> car
# Confidence ---> 0.27
# Class name --> car
# 0: 448x640 1 person, 2 cars, 88.3ms
# Speed: 3.0ms preprocess, 88.3ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.31
# Class name --> person
# 0: 448x640 1 person, 99.6ms
# Speed: 3.0ms preprocess, 99.6ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.44
# Class name --> person
# 0: 448x640 1 person, 99.1ms
# Speed: 3.0ms preprocess, 99.1ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.44
# Class name --> person
# 0: 448x640 1 person, 91.5ms
# Speed: 3.0ms preprocess, 91.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.59
# Class name --> person
# 0: 448x640 1 person, 99.6ms
# Speed: 3.8ms preprocess, 99.6ms inference, 2.9ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.26
# Class name --> person
# 0: 448x640 1 person, 105.1ms
# Speed: 2.9ms preprocess, 105.1ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 86.5ms
# Speed: 3.0ms preprocess, 86.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.37
# Class name --> person
# 0: 448x640 1 person, 82.4ms
# Speed: 2.0ms preprocess, 82.4ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.5
# Class name --> person
# 0: 448x640 1 person, 81.5ms
# Speed: 3.0ms preprocess, 81.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.47
# Class name --> person
# 0: 448x640 1 person, 94.2ms
# Speed: 3.0ms preprocess, 94.2ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.27
# Class name --> person
# 0: 448x640 1 person, 84.5ms
# Speed: 2.0ms preprocess, 84.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.4
# Class name --> person
# 0: 448x640 1 person, 85.5ms
# Speed: 3.0ms preprocess, 85.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.46
# Class name --> person
# 0: 448x640 1 person, 88.1ms
# Speed: 3.0ms preprocess, 88.1ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.58
# Class name --> person
# 0: 448x640 1 person, 94.0ms
# Speed: 2.0ms preprocess, 94.0ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.44
# Class name --> person
# 0: 448x640 1 person, 93.5ms
# Speed: 4.0ms preprocess, 93.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.3
# Class name --> person
# 0: 448x640 1 person, 102.8ms
# Speed: 2.0ms preprocess, 102.8ms inference, 2.3ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.56
# Class name --> person
# 0: 448x640 1 person, 103.9ms
# Speed: 2.7ms preprocess, 103.9ms inference, 3.2ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.67
# Class name --> person
# 0: 448x640 1 person, 101.4ms
# Speed: 4.0ms preprocess, 101.4ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.63
# Class name --> person
# 0: 448x640 1 person, 90.0ms
# Speed: 3.5ms preprocess, 90.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 83.0ms
# Speed: 3.0ms preprocess, 83.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 99.5ms
# Speed: 4.0ms preprocess, 99.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.45
# Class name --> person
# 0: 448x640 1 person, 82.5ms
# Speed: 2.0ms preprocess, 82.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.45
# Class name --> person
# 0: 448x640 1 person, 102.5ms
# Speed: 3.0ms preprocess, 102.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.58
# Class name --> person
# 0: 448x640 1 person, 98.5ms
# Speed: 4.0ms preprocess, 98.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 100.6ms
# Speed: 3.0ms preprocess, 100.6ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 104.7ms
# Speed: 3.7ms preprocess, 104.7ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.56
# Class name --> person
# 0: 448x640 1 person, 90.4ms
# Speed: 3.9ms preprocess, 90.4ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.51
# Class name --> person
# 0: 448x640 1 person, 91.5ms
# Speed: 4.0ms preprocess, 91.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.31
# Class name --> person
# 0: 448x640 1 person, 87.5ms
# Speed: 4.0ms preprocess, 87.5ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 91.2ms
# Speed: 3.3ms preprocess, 91.2ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 89.5ms
# Speed: 2.0ms preprocess, 89.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.45
# Class name --> person
# 0: 448x640 1 person, 98.5ms
# Speed: 4.0ms preprocess, 98.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.53
# Class name --> person
# 0: 448x640 1 person, 94.5ms
# Speed: 4.0ms preprocess, 94.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.44
# Class name --> person
# 0: 448x640 1 person, 96.0ms
# Speed: 3.0ms preprocess, 96.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 90.5ms
# Speed: 4.0ms preprocess, 90.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.39
# Class name --> person
# 0: 448x640 1 person, 104.5ms
# Speed: 2.0ms preprocess, 104.5ms inference, 2.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 99.1ms
# Speed: 4.5ms preprocess, 99.1ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.56
# Class name --> car
# 0: 448x640 1 car, 90.5ms
# Speed: 4.0ms preprocess, 90.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.69
# Class name --> car
# 0: 448x640 1 car, 111.0ms
# Speed: 4.0ms preprocess, 111.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.76
# Class name --> car
# 0: 448x640 1 car, 93.5ms
# Speed: 2.0ms preprocess, 93.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.64
# Class name --> car
# 0: 448x640 1 car, 94.5ms
# Speed: 2.0ms preprocess, 94.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.39
# Class name --> car
# Confidence ---> 0.27
# Class name --> person
# 0: 448x640 1 person, 1 car, 92.9ms
# Speed: 3.0ms preprocess, 92.9ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.74
# Class name --> car
# Confidence ---> 0.41
# Class name --> person
# 0: 448x640 1 person, 1 car, 101.1ms
# Speed: 7.0ms preprocess, 101.1ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.78
# Class name --> car
# 0: 448x640 1 car, 88.5ms
# Speed: 3.0ms preprocess, 88.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.84
# Class name --> car
# Confidence ---> 0.31
# Class name --> person
# 0: 448x640 1 person, 1 car, 108.2ms
# Speed: 3.0ms preprocess, 108.2ms inference, 3.3ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.67
# Class name --> car
# 0: 448x640 1 car, 105.9ms
# Speed: 3.0ms preprocess, 105.9ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.58
# Class name --> car
# Confidence ---> 0.37
# Class name --> person
# 0: 448x640 1 person, 1 car, 95.5ms
# Speed: 4.0ms preprocess, 95.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.77
# Class name --> car
# 0: 448x640 1 car, 91.5ms
# Speed: 2.0ms preprocess, 91.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.62
# Class name --> car
# 0: 448x640 1 car, 93.5ms
# Speed: 4.0ms preprocess, 93.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.78
# Class name --> car
# 0: 448x640 1 car, 88.5ms
# Speed: 4.0ms preprocess, 88.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.46
# Class name --> car
# Confidence ---> 0.28
# Class name --> person
# 0: 448x640 1 person, 1 car, 93.5ms
# Speed: 4.0ms preprocess, 93.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.62
# Class name --> car
# Confidence ---> 0.44
# Class name --> person
# 0: 448x640 1 person, 1 car, 99.1ms
# Speed: 3.0ms preprocess, 99.1ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.54
# Class name --> car
# 0: 448x640 1 car, 92.2ms
# Speed: 3.0ms preprocess, 92.2ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 94.9ms
# Speed: 3.1ms preprocess, 94.9ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.3
# Class name --> person
# 0: 448x640 1 person, 97.5ms
# Speed: 3.0ms preprocess, 97.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# 0: 448x640 2 persons, 99.2ms
# Speed: 3.0ms preprocess, 99.2ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# 0: 448x640 2 persons, 100.0ms
# Speed: 3.3ms preprocess, 100.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# 0: 448x640 2 persons, 97.5ms
# Speed: 3.0ms preprocess, 97.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# 0: 448x640 2 persons, 100.5ms
# Speed: 3.0ms preprocess, 100.5ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.49
# Class name --> person
# 0: 448x640 1 person, 97.5ms
# Speed: 4.0ms preprocess, 97.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# 0: 448x640 2 persons, 98.9ms
# Speed: 4.0ms preprocess, 98.9ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# 0: 448x640 2 persons, 83.2ms
# Speed: 3.0ms preprocess, 83.2ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.44
# Class name --> person
# 0: 448x640 1 person, 89.5ms
# Speed: 2.0ms preprocess, 89.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.48
# Class name --> person
# 0: 448x640 1 person, 89.5ms
# Speed: 2.0ms preprocess, 89.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.42
# Class name --> person
# 0: 448x640 1 person, 102.4ms
# Speed: 3.5ms preprocess, 102.4ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.55
# Class name --> person
# 0: 448x640 1 person, 96.4ms
# Speed: 3.5ms preprocess, 96.4ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.47
# Class name --> person
# 0: 448x640 1 person, 99.5ms
# Speed: 3.0ms preprocess, 99.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.62
# Class name --> person
# 0: 448x640 1 person, 93.5ms
# Speed: 3.0ms preprocess, 93.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# 0: 448x640 2 persons, 97.1ms
# Speed: 3.0ms preprocess, 97.1ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.26
# Class name --> person
# 0: 448x640 1 person, 93.1ms
# Speed: 4.0ms preprocess, 93.1ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 82.5ms
# Speed: 2.0ms preprocess, 82.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.36
# Class name --> person
# 0: 448x640 1 person, 93.5ms
# Speed: 2.0ms preprocess, 93.5ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.32
# Class name --> person
# 0: 448x640 1 person, 86.5ms
# Speed: 4.0ms preprocess, 86.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 88.5ms
# Speed: 3.0ms preprocess, 88.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.33
# Class name --> person
# 0: 448x640 1 person, 97.5ms
# Speed: 2.0ms preprocess, 97.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.26
# Class name --> person
# 0: 448x640 1 person, 104.1ms
# Speed: 2.6ms preprocess, 104.1ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 99.4ms
# Speed: 2.6ms preprocess, 99.4ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 89.1ms
# Speed: 4.0ms preprocess, 89.1ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 86.5ms
# Speed: 1.0ms preprocess, 86.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 99.5ms
# Speed: 4.0ms preprocess, 99.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 108.5ms
# Speed: 4.0ms preprocess, 108.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 90.5ms
# Speed: 2.0ms preprocess, 90.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 93.5ms
# Speed: 2.0ms preprocess, 93.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 99.0ms
# Speed: 4.0ms preprocess, 99.0ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 104.4ms
# Speed: 2.6ms preprocess, 104.4ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 92.8ms
# Speed: 3.8ms preprocess, 92.8ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 95.5ms
# Speed: 3.0ms preprocess, 95.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 93.1ms
# Speed: 2.0ms preprocess, 93.1ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 88.5ms
# Speed: 2.0ms preprocess, 88.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 88.5ms
# Speed: 3.0ms preprocess, 88.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 88.5ms
# Speed: 2.0ms preprocess, 88.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 102.5ms
# Speed: 4.0ms preprocess, 102.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 102.5ms
# Speed: 4.0ms preprocess, 102.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 109.5ms
# Speed: 3.0ms preprocess, 109.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 119.5ms
# Speed: 4.0ms preprocess, 119.5ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 123.0ms
# Speed: 3.6ms preprocess, 123.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.37
# Class name --> person
# 0: 448x640 1 person, 98.5ms
# Speed: 4.0ms preprocess, 98.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.28
# Class name --> person
# 0: 448x640 1 person, 101.5ms
# Speed: 4.0ms preprocess, 101.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 97.5ms
# Speed: 2.0ms preprocess, 97.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 83.5ms
# Speed: 2.0ms preprocess, 83.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 96.5ms
# Speed: 3.0ms preprocess, 96.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.41
# Class name --> person
# 0: 448x640 1 person, 97.5ms
# Speed: 2.0ms preprocess, 97.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 98.5ms
# Speed: 3.0ms preprocess, 98.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.34
# Class name --> person
# 0: 448x640 1 person, 108.8ms
# Speed: 3.1ms preprocess, 108.8ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.59
# Class name --> person
# 0: 448x640 1 person, 101.8ms
# Speed: 3.7ms preprocess, 101.8ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.55
# Class name --> person
# 0: 448x640 1 person, 97.1ms
# Speed: 2.0ms preprocess, 97.1ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.55
# Class name --> person
# 0: 448x640 1 person, 95.5ms
# Speed: 4.0ms preprocess, 95.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.28
# Class name --> person
# 0: 448x640 1 person, 95.5ms
# Speed: 3.0ms preprocess, 95.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.26
# Class name --> person
# 0: 448x640 1 person, 87.5ms
# Speed: 2.0ms preprocess, 87.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.37
# Class name --> person
# 0: 448x640 1 person, 92.5ms
# Speed: 4.0ms preprocess, 92.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.42
# Class name --> person
# 0: 448x640 1 person, 99.5ms
# Speed: 3.0ms preprocess, 99.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.34
# Class name --> person
# 0: 448x640 1 person, 96.5ms
# Speed: 4.0ms preprocess, 96.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 99.1ms
# Speed: 3.0ms preprocess, 99.1ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.39
# Class name --> person
# 0: 448x640 1 person, 104.0ms
# Speed: 3.0ms preprocess, 104.0ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.44
# Class name --> person
# 0: 448x640 1 person, 98.4ms
# Speed: 2.6ms preprocess, 98.4ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.39
# Class name --> person
# 0: 448x640 1 person, 92.9ms
# Speed: 2.1ms preprocess, 92.9ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.45
# Class name --> person
# 0: 448x640 1 person, 96.5ms
# Speed: 4.0ms preprocess, 96.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.56
# Class name --> person
# 0: 448x640 1 person, 88.5ms
# Speed: 2.0ms preprocess, 88.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.58
# Class name --> person
# 0: 448x640 1 person, 95.5ms
# Speed: 3.0ms preprocess, 95.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.45
# Class name --> person
# 0: 448x640 1 person, 97.6ms
# Speed: 2.0ms preprocess, 97.6ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.41
# Class name --> person
# 0: 448x640 1 person, 93.5ms
# Speed: 3.0ms preprocess, 93.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.52
# Class name --> person
# 0: 448x640 1 person, 99.1ms
# Speed: 3.0ms preprocess, 99.1ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.6
# Class name --> person
# 0: 448x640 1 person, 104.4ms
# Speed: 2.0ms preprocess, 104.4ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.56
# Class name --> person
# 0: 448x640 1 person, 102.1ms
# Speed: 2.7ms preprocess, 102.1ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.48
# Class name --> person
# 0: 448x640 1 person, 91.5ms
# Speed: 2.0ms preprocess, 91.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.49
# Class name --> person
# 0: 448x640 1 person, 93.6ms
# Speed: 3.0ms preprocess, 93.6ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.39
# Class name --> car
# 0: 448x640 1 person, 1 car, 97.5ms
# Speed: 3.0ms preprocess, 97.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.71
# Class name --> car
# Confidence ---> 0.54
# Class name --> person
# 0: 448x640 1 person, 1 car, 97.5ms
# Speed: 3.0ms preprocess, 97.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.59
# Class name --> car
# Confidence ---> 0.5
# Class name --> person
# 0: 448x640 1 person, 1 car, 121.1ms
# Speed: 2.0ms preprocess, 121.1ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.73
# Class name --> car
# Confidence ---> 0.29
# Class name --> person
# 0: 448x640 1 person, 1 car, 90.4ms
# Speed: 3.5ms preprocess, 90.4ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.59
# Class name --> car
# Confidence ---> 0.4
# Class name --> person
# 0: 448x640 1 person, 1 car, 94.5ms
# Speed: 4.0ms preprocess, 94.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.66
# Class name --> car
# Confidence ---> 0.44
# Class name --> person
# 0: 448x640 1 person, 1 car, 96.5ms
# Speed: 2.0ms preprocess, 96.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.52
# Class name --> car
# Confidence ---> 0.26
# Class name --> car
# 0: 448x640 1 person, 2 cars, 80.5ms
# Speed: 3.0ms preprocess, 80.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.74
# Class name --> car
# Confidence ---> 0.48
# Class name --> person
# 0: 448x640 1 person, 1 car, 99.2ms
# Speed: 3.0ms preprocess, 99.2ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.65
# Class name --> car
# Confidence ---> 0.51
# Class name --> person
# 0: 448x640 1 person, 1 car, 100.3ms
# Speed: 1.5ms preprocess, 100.3ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.77
# Class name --> car
# Confidence ---> 0.39
# Class name --> person
# 0: 448x640 1 person, 1 car, 92.5ms
# Speed: 4.0ms preprocess, 92.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.84
# Class name --> car
# Confidence ---> 0.37
# Class name --> person
# 0: 448x640 1 person, 1 car, 92.5ms
# Speed: 2.0ms preprocess, 92.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.84
# Class name --> car
# Confidence ---> 0.45
# Class name --> person
# 0: 448x640 1 person, 1 car, 95.1ms
# Speed: 3.0ms preprocess, 95.1ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.8
# Class name --> car
# Confidence ---> 0.71
# Class name --> car
# Confidence ---> 0.45
# Class name --> person
# 0: 448x640 1 person, 2 cars, 98.7ms
# Speed: 3.5ms preprocess, 98.7ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.78
# Class name --> car
# Confidence ---> 0.74
# Class name --> car
# Confidence ---> 0.45
# Class name --> person
# 0: 448x640 1 person, 2 cars, 92.5ms
# Speed: 4.0ms preprocess, 92.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.77
# Class name --> car
# Confidence ---> 0.67
# Class name --> car
# 0: 448x640 2 cars, 95.5ms
# Speed: 2.0ms preprocess, 95.5ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.78
# Class name --> car
# Confidence ---> 0.73
# Class name --> car
# Confidence ---> 0.26
# Class name --> person
# 0: 448x640 1 person, 2 cars, 101.5ms
# Speed: 3.0ms preprocess, 101.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.76
# Class name --> car
# Confidence ---> 0.58
# Class name --> car
# Confidence ---> 0.4
# Class name --> person
# 0: 448x640 1 person, 2 cars, 101.8ms
# Speed: 2.0ms preprocess, 101.8ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.8
# Class name --> car
# Confidence ---> 0.67
# Class name --> car
# Confidence ---> 0.37
# Class name --> person
# 0: 448x640 1 person, 2 cars, 97.0ms
# Speed: 2.9ms preprocess, 97.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.82
# Class name --> car
# Confidence ---> 0.6
# Class name --> car
# Confidence ---> 0.38
# Class name --> person
# 0: 448x640 1 person, 2 cars, 88.5ms
# Speed: 2.0ms preprocess, 88.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.84
# Class name --> car
# Confidence ---> 0.66
# Class name --> car
# Confidence ---> 0.29
# Class name --> person
# 0: 448x640 1 person, 2 cars, 96.5ms
# Speed: 4.0ms preprocess, 96.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.81
# Class name --> car
# 0: 448x640 1 car, 95.4ms
# Speed: 4.0ms preprocess, 95.4ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.85
# Class name --> car
# 0: 448x640 1 car, 92.2ms
# Speed: 1.9ms preprocess, 92.2ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.6
# Class name --> car
# Confidence ---> 0.3
# Class name --> person
# 0: 448x640 1 person, 1 car, 92.5ms
# Speed: 3.0ms preprocess, 92.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.87
# Class name --> car
# 0: 448x640 1 car, 94.5ms
# Speed: 3.0ms preprocess, 94.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.69
# Class name --> car
# 0: 448x640 1 car, 89.5ms
# Speed: 2.0ms preprocess, 89.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.78
# Class name --> car
# 0: 448x640 1 car, 95.5ms
# Speed: 2.0ms preprocess, 95.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 94.0ms
# Speed: 2.0ms preprocess, 94.0ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 105.6ms
# Speed: 3.0ms preprocess, 105.6ms inference, 2.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 99.2ms
# Speed: 4.4ms preprocess, 99.2ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 90.4ms
# Speed: 2.0ms preprocess, 90.4ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.31
# Class name --> truck
# 0: 448x640 1 truck, 97.6ms
# Speed: 3.0ms preprocess, 97.6ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.82
# Class name --> car
# 0: 448x640 1 car, 88.5ms
# Speed: 3.0ms preprocess, 88.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.84
# Class name --> car
# 0: 448x640 1 car, 96.3ms
# Speed: 3.0ms preprocess, 96.3ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.32
# Class name --> truck
# Confidence ---> 0.3
# Class name --> car
# 0: 448x640 1 car, 1 truck, 94.5ms
# Speed: 3.0ms preprocess, 94.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.64
# Class name --> car
# 0: 448x640 1 car, 96.5ms
# Speed: 3.0ms preprocess, 96.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.81
# Class name --> car
# 0: 448x640 1 car, 100.2ms
# Speed: 2.0ms preprocess, 100.2ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.78
# Class name --> car
# 0: 448x640 1 car, 110.9ms
# Speed: 3.7ms preprocess, 110.9ms inference, 3.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.84
# Class name --> car
# 0: 448x640 1 car, 99.3ms
# Speed: 2.7ms preprocess, 99.3ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.83
# Class name --> car
# 0: 448x640 1 car, 89.1ms
# Speed: 3.0ms preprocess, 89.1ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.82
# Class name --> car
# 0: 448x640 1 car, 101.0ms
# Speed: 3.0ms preprocess, 101.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.46
# Class name --> car
# 0: 448x640 1 car, 94.5ms
# Speed: 3.0ms preprocess, 94.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.76
# Class name --> car
# 0: 448x640 1 car, 91.5ms
# Speed: 2.0ms preprocess, 91.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.64
# Class name --> car
# 0: 448x640 1 car, 92.5ms
# Speed: 3.0ms preprocess, 92.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.52
# Class name --> car
# 0: 448x640 1 car, 92.5ms
# Speed: 2.0ms preprocess, 92.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.74
# Class name --> car
# 0: 448x640 1 car, 101.3ms
# Speed: 2.0ms preprocess, 101.3ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.39
# Class name --> car
# 0: 448x640 1 car, 95.5ms
# Speed: 2.0ms preprocess, 95.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 100.7ms
# Speed: 2.0ms preprocess, 100.7ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 103.9ms
# Speed: 4.0ms preprocess, 103.9ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 96.3ms
# Speed: 2.1ms preprocess, 96.3ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 82.5ms
# Speed: 3.0ms preprocess, 82.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.44
# Class name --> car
# Confidence ---> 0.31
# Class name --> car
# 0: 448x640 2 cars, 92.5ms
# Speed: 2.0ms preprocess, 92.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.63
# Class name --> car
# 0: 448x640 1 car, 96.5ms
# Speed: 2.0ms preprocess, 96.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.53
# Class name --> car
# 0: 448x640 1 car, 87.5ms
# Speed: 2.0ms preprocess, 87.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.32
# Class name --> car
# 0: 448x640 1 car, 85.5ms
# Speed: 3.0ms preprocess, 85.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.37
# Class name --> car
# 0: 448x640 1 car, 97.2ms
# Speed: 3.0ms preprocess, 97.2ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.66
# Class name --> car
# Confidence ---> 0.41
# Class name --> car
# 0: 448x640 2 cars, 105.3ms
# Speed: 3.8ms preprocess, 105.3ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.75
# Class name --> car
# 0: 448x640 1 car, 106.5ms
# Speed: 3.3ms preprocess, 106.5ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.79
# Class name --> car
# 0: 448x640 1 car, 94.5ms
# Speed: 4.0ms preprocess, 94.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.8
# Class name --> car
# 0: 448x640 1 car, 99.5ms
# Speed: 2.0ms preprocess, 99.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.73
# Class name --> car
# 0: 448x640 1 car, 88.0ms
# Speed: 4.0ms preprocess, 88.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.47
# Class name --> car
# 0: 448x640 1 car, 85.5ms
# Speed: 3.0ms preprocess, 85.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.4
# Class name --> car
# 0: 448x640 1 car, 91.6ms
# Speed: 2.5ms preprocess, 91.6ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.38
# Class name --> car
# 0: 448x640 1 car, 84.5ms
# Speed: 2.0ms preprocess, 84.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.33
# Class name --> car
# 0: 448x640 1 car, 93.5ms
# Speed: 3.0ms preprocess, 93.5ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.69
# Class name --> car
# 0: 448x640 1 car, 84.1ms
# Speed: 3.0ms preprocess, 84.1ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.55
# Class name --> car
# 0: 448x640 1 car, 101.3ms
# Speed: 3.0ms preprocess, 101.3ms inference, 2.6ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.36
# Class name --> car
# 0: 448x640 1 car, 105.9ms
# Speed: 2.3ms preprocess, 105.9ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.57
# Class name --> car
# 0: 448x640 1 car, 97.2ms
# ...
#
# 0: 448x640 (no detections), 87.8ms
# Speed: 2.0ms preprocess, 87.8ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 100.5ms
# Speed: 2.0ms preprocess, 100.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 87.5ms
# Speed: 2.0ms preprocess, 87.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 99.5ms
# Speed: 3.0ms preprocess, 99.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 101.5ms
# Speed: 2.0ms preprocess, 101.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 87.5ms
# Speed: 2.1ms preprocess, 87.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 90.5ms
# Speed: 3.0ms preprocess, 90.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 104.6ms
# Speed: 4.0ms preprocess, 104.6ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 105.5ms
# Speed: 3.1ms preprocess, 105.5ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 94.0ms
# Speed: 3.8ms preprocess, 94.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 91.6ms
# Speed: 2.0ms preprocess, 91.6ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 89.5ms
# Speed: 3.0ms preprocess, 89.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 101.5ms
# Speed: 3.0ms preprocess, 101.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.4
# Class name --> car
# 0: 448x640 1 car, 90.5ms
# Speed: 3.0ms preprocess, 90.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.5
# Class name --> car
# 0: 448x640 1 car, 95.5ms
# Speed: 2.0ms preprocess, 95.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.53
# Class name --> car
# 0: 448x640 1 car, 100.5ms
# Speed: 4.0ms preprocess, 100.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.67
# Class name --> car
# 0: 448x640 1 car, 94.2ms
# Speed: 3.0ms preprocess, 94.2ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.74
# Class name --> car
# 0: 448x640 1 car, 101.4ms
# Speed: 4.0ms preprocess, 101.4ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.8
# Class name --> car
# Confidence ---> 0.35
# Class name --> car
# 0: 448x640 2 cars, 101.4ms
# Speed: 2.1ms preprocess, 101.4ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.69
# Class name --> car
# 0: 448x640 1 car, 76.5ms
# Speed: 2.0ms preprocess, 76.5ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.73
# Class name --> car
# Confidence ---> 0.42
# Class name --> car
# 0: 448x640 2 cars, 86.5ms
# Speed: 2.0ms preprocess, 86.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.51
# Class name --> car
# Confidence ---> 0.47
# Class name --> car
# 0: 448x640 2 cars, 92.5ms
# Speed: 3.0ms preprocess, 92.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.61
# Class name --> car
# Confidence ---> 0.46
# Class name --> car
# 0: 448x640 2 cars, 101.5ms
# Speed: 2.0ms preprocess, 101.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.79
# Class name --> car
# Confidence ---> 0.54
# Class name --> car
# 0: 448x640 2 cars, 94.5ms
# Speed: 4.0ms preprocess, 94.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.76
# Class name --> car
# Confidence ---> 0.73
# Class name --> car
# 0: 448x640 2 cars, 95.5ms
# Speed: 3.0ms preprocess, 95.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.76
# Class name --> car
# Confidence ---> 0.73
# Class name --> car
# 0: 448x640 2 cars, 100.5ms
# Speed: 3.5ms preprocess, 100.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.79
# Class name --> car
# Confidence ---> 0.75
# Class name --> car
# 0: 448x640 2 cars, 97.4ms
# Speed: 4.0ms preprocess, 97.4ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.79
# Class name --> car
# Confidence ---> 0.65
# Class name --> car
# 0: 448x640 2 cars, 102.0ms
# Speed: 3.0ms preprocess, 102.0ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.78
# Class name --> car
# Confidence ---> 0.62
# Class name --> car
# 0: 448x640 2 cars, 101.8ms
# Speed: 3.7ms preprocess, 101.8ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.57
# Class name --> car
# Confidence ---> 0.54
# Class name --> car
# 0: 448x640 2 cars, 89.2ms
# Speed: 3.3ms preprocess, 89.2ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.75
# Class name --> car
# Confidence ---> 0.69
# Class name --> car
# 0: 448x640 2 cars, 97.5ms
# Speed: 3.0ms preprocess, 97.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.75
# Class name --> car
# Confidence ---> 0.56
# Class name --> car
# 0: 448x640 2 cars, 95.9ms
# Speed: 2.0ms preprocess, 95.9ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.82
# Class name --> car
# Confidence ---> 0.52
# Class name --> car
# 0: 448x640 2 cars, 93.5ms
# Speed: 2.0ms preprocess, 93.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.86
# Class name --> car
# 0: 448x640 1 car, 98.1ms
# Speed: 3.0ms preprocess, 98.1ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.74
# Class name --> car
# 0: 448x640 1 car, 94.2ms
# Speed: 2.0ms preprocess, 94.2ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.89
# Class name --> car
# 0: 448x640 1 car, 98.9ms
# Speed: 3.0ms preprocess, 98.9ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.85
# Class name --> car
# 0: 448x640 1 car, 99.5ms
# Speed: 4.0ms preprocess, 99.5ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.84
# Class name --> car
# 0: 448x640 1 car, 115.9ms
# Speed: 2.8ms preprocess, 115.9ms inference, 3.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.77
# Class name --> car
# 0: 448x640 1 car, 106.8ms
# Speed: 3.8ms preprocess, 106.8ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.75
# Class name --> car
# Confidence ---> 0.36
# Class name --> car
# 0: 448x640 2 cars, 106.5ms
# Speed: 5.0ms preprocess, 106.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.76
# Class name --> car
# 0: 448x640 1 car, 104.5ms
# Speed: 3.0ms preprocess, 104.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.73
# Class name --> car
# Confidence ---> 0.65
# Class name --> car
# 0: 448x640 2 cars, 106.1ms
# Speed: 5.0ms preprocess, 106.1ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.83
# Class name --> car
# Confidence ---> 0.74
# Class name --> car
# 0: 448x640 2 cars, 103.8ms
# Speed: 3.0ms preprocess, 103.8ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.76
# Class name --> car
# Confidence ---> 0.41
# Class name --> car
# 0: 448x640 2 cars, 94.5ms
# Speed: 2.0ms preprocess, 94.5ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.82
# Class name --> car
# Confidence ---> 0.66
# Class name --> car
# 0: 448x640 2 cars, 100.5ms
# Speed: 4.0ms preprocess, 100.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.76
# Class name --> car
# Confidence ---> 0.52
# Class name --> car
# 0: 448x640 2 cars, 108.0ms
# Speed: 3.0ms preprocess, 108.0ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.78
# Class name --> car
# Confidence ---> 0.64
# Class name --> car
# 0: 448x640 2 cars, 102.6ms
# Speed: 3.2ms preprocess, 102.6ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.71
# Class name --> car
# Confidence ---> 0.61
# Class name --> car
# 0: 448x640 2 cars, 105.3ms
# Speed: 3.5ms preprocess, 105.3ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.63
# Class name --> car
# Confidence ---> 0.31
# Class name --> car
# 0: 448x640 2 cars, 100.5ms
# Speed: 2.5ms preprocess, 100.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.66
# Class name --> car
# 0: 448x640 1 car, 104.2ms
# Speed: 4.0ms preprocess, 104.2ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.68
# Class name --> car
# 0: 448x640 1 car, 96.5ms
# Speed: 3.0ms preprocess, 96.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.71
# Class name --> car
# 0: 448x640 1 car, 99.5ms
# Speed: 2.0ms preprocess, 99.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.38
# Class name --> car
# Confidence ---> 0.31
# Class name --> truck
# 0: 448x640 1 car, 1 truck, 93.5ms
# Speed: 4.0ms preprocess, 93.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.36
# Class name --> car
# Confidence ---> 0.34
# Class name --> truck
# 0: 448x640 1 car, 1 truck, 102.0ms
# Speed: 2.0ms preprocess, 102.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.42
# Class name --> car
# 0: 448x640 1 car, 93.5ms
# Speed: 2.0ms preprocess, 93.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.46
# Class name --> car
# Confidence ---> 0.36
# Class name --> truck
# 0: 448x640 1 car, 1 truck, 110.3ms
# Speed: 4.0ms preprocess, 110.3ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.72
# Class name --> car
# 0: 448x640 1 car, 111.4ms
# Speed: 3.8ms preprocess, 111.4ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.64
# Class name --> car
# 0: 448x640 1 car, 98.7ms
# Speed: 4.0ms preprocess, 98.7ms inference, 2.6ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.84
# Class name --> car
# 0: 448x640 1 car, 109.5ms
# Speed: 4.0ms preprocess, 109.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.66
# Class name --> car
# 0: 448x640 1 car, 138.5ms
# Speed: 5.0ms preprocess, 138.5ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.63
# Class name --> car
# 0: 448x640 1 car, 103.5ms
# Speed: 3.9ms preprocess, 103.5ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 97.1ms
# Speed: 2.0ms preprocess, 97.1ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.78
# Class name --> car
# 0: 448x640 1 car, 96.5ms
# Speed: 4.0ms preprocess, 96.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.67
# Class name --> car
# 0: 448x640 1 car, 96.5ms
# Speed: 2.0ms preprocess, 96.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.69
# Class name --> car
# Confidence ---> 0.59
# Class name --> car
# 0: 448x640 2 cars, 106.7ms
# Speed: 4.0ms preprocess, 106.7ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.82
# Class name --> car
# 0: 448x640 1 car, 113.0ms
# Speed: 2.7ms preprocess, 113.0ms inference, 3.2ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.78
# Class name --> car
# Confidence ---> 0.48
# Class name --> car
# 0: 448x640 2 cars, 103.5ms
# Speed: 3.0ms preprocess, 103.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.7
# Class name --> car
# 0: 448x640 1 car, 93.1ms
# Speed: 3.0ms preprocess, 93.1ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.74
# Class name --> car
# 0: 448x640 1 car, 93.5ms
# Speed: 2.0ms preprocess, 93.5ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.88
# Class name --> car
# 0: 448x640 1 car, 98.5ms
# Speed: 2.0ms preprocess, 98.5ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.78
# Class name --> car
# 0: 448x640 1 car, 102.5ms
# Speed: 2.5ms preprocess, 102.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.65
# Class name --> car
# Confidence ---> 0.37
# Class name --> truck
# 0: 448x640 1 car, 1 truck, 100.5ms
# Speed: 2.0ms preprocess, 100.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.68
# Class name --> car
# 0: 448x640 1 car, 101.5ms
# Speed: 2.0ms preprocess, 101.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.72
# Class name --> car
# 0: 448x640 1 car, 107.5ms
# Speed: 4.0ms preprocess, 107.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.8
# Class name --> car
# 0: 448x640 1 car, 112.9ms
# Speed: 3.0ms preprocess, 112.9ms inference, 2.6ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.7
# Class name --> car
# 0: 448x640 1 car, 105.7ms
# Speed: 3.9ms preprocess, 105.7ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.82
# Class name --> car
# 0: 448x640 1 car, 105.5ms
# Speed: 4.0ms preprocess, 105.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.77
# Class name --> car
# 0: 448x640 1 car, 88.5ms
# Speed: 4.0ms preprocess, 88.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.68
# Class name --> car
# 0: 448x640 1 car, 96.4ms
# Speed: 3.0ms preprocess, 96.4ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.56
# Class name --> car
# 0: 448x640 1 car, 87.5ms
# Speed: 3.0ms preprocess, 87.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.62
# Class name --> car
# 0: 448x640 1 car, 104.5ms
# Speed: 3.0ms preprocess, 104.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.77
# Class name --> car
# Confidence ---> 0.27
# Class name --> car
# 0: 448x640 2 cars, 99.5ms
# Speed: 2.0ms preprocess, 99.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.63
# Class name --> car
# Confidence ---> 0.32
# Class name --> car
# 0: 448x640 2 cars, 97.2ms
# Speed: 2.0ms preprocess, 97.2ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.63
# Class name --> car
# Confidence ---> 0.3
# Class name --> car
# 0: 448x640 2 cars, 109.0ms
# Speed: 2.0ms preprocess, 109.0ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.75
# Class name --> car
# Confidence ---> 0.7
# Class name --> car
# 0: 448x640 2 cars, 107.3ms
# Speed: 3.2ms preprocess, 107.3ms inference, 3.3ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.6
# Class name --> car
# Confidence ---> 0.5
# Class name --> car
# Confidence ---> 0.33
# Class name --> car
# 0: 448x640 3 cars, 106.2ms
# Speed: 3.9ms preprocess, 106.2ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.66
# Class name --> car
# Confidence ---> 0.48
# Class name --> car
# 0: 448x640 2 cars, 108.5ms
# Speed: 3.0ms preprocess, 108.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.61
# Class name --> car
# Confidence ---> 0.55
# Class name --> car
# 0: 448x640 2 cars, 96.5ms
# Speed: 3.0ms preprocess, 96.5ms inference, 2.3ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.77
# Class name --> car
# Confidence ---> 0.36
# Class name --> car
# 0: 448x640 2 cars, 103.5ms
# Speed: 3.0ms preprocess, 103.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Confidence ---> 0.88
# Class name --> car
# 0: 448x640 1 car, 98.5ms
# Speed: 3.0ms preprocess, 98.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)

# %%
for box in boxes:
    print(box)
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.7712])
# data: tensor([[149.3134, 263.3203, 222.5858, 296.8741,   0.7712,   2.0000]])
# id: None
# is_track: False
# orig_shape: (480, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[185.9496, 280.0972,  73.2724,  33.5538]])
# xywhn: tensor([[0.2583, 0.5835, 0.1018, 0.0699]])
# xyxy: tensor([[149.3134, 263.3203, 222.5858, 296.8741]])
# xyxyn: tensor([[0.2074, 0.5486, 0.3091, 0.6185]])

# %%
while True:
    success, img = cap.read()
    results = model(img, stream=True)

    # coordinates
    for r in results:
        boxes = r.boxes

        for box in boxes:
            # bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

            # put box in cam
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # confidence
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # object details
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
